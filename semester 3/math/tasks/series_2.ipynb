# %%
# import needed libraries for all plot and numbering stuff
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# [CONFIGS] --------------------------------------
mpl.rcParams['figure.dpi'] = 120

# %% [markdown]
# ![](./thumbnail.jpg)
#
# # **Serie 2**

# %% [markdown]
# ## Aufgabe 2.1

# %%
data_geysir = pd.read_csv("./geysir.dat", delimiter=' ', index_col=0)
data_geysir
# Out:
#      Tag  Zeitspanne  Eruptionsdauer
# 1      1          78             4.4
# 2      1          74             3.9
# 3      1          68             4.0
# 4      1          76             4.0
# 5      1          80             3.5
# ..   ...         ...             ...
# 103    8          61             1.9
# 104    8          81             4.5
# 105    8          51             2.0
# 106    8          80             4.8
# 107    8          79             4.1
#
# [107 rows x 3 columns]

# %%
# (2 2 1)
#  │ │ └── select first figure
#  │ └──── two columns
#  └────── two rows
plt.subplot(221)
data_geysir["Zeitspanne"].plot(kind="hist", edgecolor="black")
plt.xlabel("10 Klassen")
plt.subplot(222)
data_geysir["Zeitspanne"].plot(kind="hist",
                               bins=20,
                               edgecolor="black")
plt.xlabel("20 Klassen")
plt.subplot(223)
# select specific points
data_geysir["Zeitspanne"].plot(kind="hist",
                               bins=np.arange(41, 107, 11),
                               edgecolor="black")
plt.xlabel("Klassengrenzen 41, 52 , 63, 74 , 85, 96")
plt.tight_layout()

print("a)")
plt.show()
# Out:
# a)

# %% [markdown]
# Anhand den ersten zwei Histogrammen kann erkannt werden, dass nicht nur bei ca. 55 Minuten häufig die Intervallen sind, sondern auch zwischen 75 - 85 Minuten entstehen.
#
# Bei Figur 3 wurde die Klassengrösse falsch gewählt und somit sind Informationen verdeckt, welche bei kleineren Klassen einfacher zu erkennen sind.

# %%
# b)
plt.subplot(221)
data_geysir["Eruptionsdauer"].plot(kind="hist",
bins = 5,
edgecolor="black")
plt.xlabel("5 Klassen")
plt.subplot(222)
data_geysir["Eruptionsdauer"].plot(kind="hist",
                               bins=10,
                               edgecolor="black")
plt.xlabel("10 Klassen")
plt.subplot(223)
data_geysir["Eruptionsdauer"].plot(kind="hist",
                               bins=20,
                               edgecolor="black")
plt.xlabel("20 Klassen")
plt.subplot(224)
data_geysir["Eruptionsdauer"].plot(kind="hist",
                              bins=30,
                               edgecolor="black")
plt.xlabel("30 Klassen")
plt.tight_layout()

print("a)")
plt.show()
# Out:
# a)

# %% [markdown]
# Entweder dauert die Eruption $<1$ Minuten oder verteilt sich im Bereich $3$ bis $4.6$ Minuten. Bei den gewählten Klassengrössen konnte bei jedem die auffälligsten Informationen gefunden werden.
#
# **Von Lösung**:
# Ob die Dauer eines Ausbruchs aber etwas zu tun hat mit der Dauer des vorangegangenen Ruheintervalls (mit anderen Worten: ob die Gipfel des Histogramms aus Teilaufgabe b) den Gipfeln der Histogramme aus Teilaufgabe a)
# entsprechen), kann man aufgrund dieser Darstellungen nicht sagen.

# %%
data_geysir["Eruptionsdauer"].plot(kind="hist",
                                   density=True,
                                   cumulative=True)
plt.yticks(np.arange(0,1,0.05))
plt.grid(True)
plt.show()

# %% [markdown]
# i) 23%
#
# ii) ~4 Minuten

# %% [markdown]
# ## Aufgabe 2.3

# %%
grades = pd.Series([4.2, 2.3, 5.6, 4.5, 4.8, 3.9, 5.9, 2.4, 5.9, 6, 4, 3.7, 5, 5.2, 4.5, 3.6, 5, 6, 2.8, 3.3, 5.5, 4.2, 4.9, 5.1])

# a)

grades_edited = grades.copy()
grades_edited[1] = 1.1
grades_edited[6] = 6
grades_edited[18] = 3.0

print(f"Original -> median: {grades.median()} mean: {grades.mean()}")
print(f"Edited -> median: {grades_edited.median()} mean: {grades_edited.mean()}")
# Out:
# Original -> median: 4.65 mean: 4.5125
# Edited -> median: 4.65 mean: 4.4750000000000005

# %%
# b)

plt.subplot(221)
grades.plot(kind="hist")
plt.ylabel("Anzahl")

plt.subplot(222)
grades.plot(kind="box")

plt.subplot(223)
grades_edited.plot(kind="hist")
plt.ylabel("Anzahl")

plt.subplot(224)
grades_edited.plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Aufgabe 2.3

# %%
schlamm = pd.read_csv("./klaerschlamm.dat", sep=" ", index_col=0)
schlamm = schlamm.drop("Labor",1)
schlamm
# Out:
# C:\Users\joelv\AppData\Local\Temp\ipykernel_16936\3644112085.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   schlamm = schlamm.drop("Labor",1)
#     Pr1  Pr2  Pr3  Pr4  Pr5  Pr6  Pr7  Pr8  Pr9
# 1   233  491  428  376  200  364  474  444  351
# 2   253  530  453  389  191  402  495  453  371
# 3   240  530  460  390  200  390  480  440  350
# 4   243  518  456  389  186  385  483  459  369
# 5   244  521  446  392  193  385  481  451  357
# 6   257  547  459  407  198  382  502  462  466
# 7   252  477  414  391  190  366  456  387  339
# 8   263  530  458  420  221  389  493  475  378
# 9   262  530  454  408  182  388  496  468  382
# 10  260  554  472  426  211  404  488  483  383
# 11  243  527  444  369  163  393  492  456  351
# 12  226  470  416  373  178  347  445  323  387
# 13  239  529  425  375  188  357  460  430  335
# 14  239  501  422  402  171  337  444  416  363
# ...

# %%
# a)
print(schlamm.describe())
schlamm.plot(kind="box")
# Out:
#               Pr1         Pr2         Pr3         Pr4         Pr5         Pr6  \
# count   21.000000   21.000000   21.000000   21.000000   21.000000   21.000000
# mean   246.142857  511.428571  443.428571  389.238095  188.238095  394.857143
# std     18.210672   76.962050   34.156363   56.642656   16.866845   56.642110
# min    216.000000  268.000000  378.000000  223.000000  157.000000  337.000000
# 25%    239.000000  491.000000  422.000000  373.000000  178.000000  366.000000
# 50%    244.000000  521.000000  446.000000  390.000000  188.000000  385.000000
# 75%    257.000000  530.000000  459.000000  405.000000  200.000000  393.000000
# max    296.000000  732.000000  548.000000  562.000000  221.000000  557.000000
#
#               Pr7         Pr8         Pr9
# count   21.000000   21.000000   21.000000
# mean   465.523810  449.952381  388.904762
# std     91.361162   57.069673  104.159927
# min    110.000000  323.000000  319.000000
# 25%    456.000000  423.000000  350.000000
# ...

# %% [markdown]
# Probe Nr 1 & 5  scheint keine Ausreiser über 400mg/kg anzuzeigen, daher ist es möglich, dass die wahren Konzentrationen unter 400mg/kg sind.

# %%
# b)
schlamm_centered = schlamm - schlamm.median()
schlamm_centered.T.plot(kind="box")
plt.grid(True)
schlamm_centered
# Out:
#      Pr1    Pr2    Pr3    Pr4   Pr5    Pr6    Pr7    Pr8    Pr9
# 1  -11.0  -30.0  -18.0  -14.0  12.0  -21.0   -7.0   -7.0  -18.0
# 2    9.0    9.0    7.0   -1.0   3.0   17.0   14.0    2.0    2.0
# 3   -4.0    9.0   14.0    0.0  12.0    5.0   -1.0  -11.0  -19.0
# 4   -1.0   -3.0   10.0   -1.0  -2.0    0.0    2.0    8.0    0.0
# 5    0.0    0.0    0.0    2.0   5.0    0.0    0.0    0.0  -12.0
# 6   13.0   26.0   13.0   17.0  10.0   -3.0   21.0   11.0   97.0
# 7    8.0  -44.0  -32.0    1.0   2.0  -19.0  -25.0  -64.0  -30.0
# 8   19.0    9.0   12.0   30.0  33.0    4.0   12.0   24.0    9.0
# 9   18.0    9.0    8.0   18.0  -6.0    3.0   15.0   17.0   13.0
# 10  16.0   33.0   26.0   36.0  23.0   19.0    7.0   32.0   14.0
# 11  -1.0    6.0   -2.0  -21.0 -25.0    8.0   11.0    5.0  -18.0
# 12 -18.0  -51.0  -30.0  -17.0 -10.0  -38.0  -36.0 -128.0   18.0
# 13  -5.0    8.0  -21.0  -15.0   0.0  -28.0  -21.0  -21.0  -34.0
# 14  -5.0  -20.0  -24.0   12.0 -17.0  -48.0  -37.0  -35.0   -6.0
# ...

# %% [markdown]
# Labor 21 scheint sehr grosse Messfehler anzuzeigen (Daten verteilen sich gross).

# %%
income = pd.read_csv("./income.dat", sep=" ")


f, (ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(income["Income2005"])
#income.plot(kind="scatter", y="Income2005", x="Educ")
#income.plot(kind="scatter", y="Income2005", x="AFQT")
# Out:
# <AxesSubplot:xlabel='AFQT', ylabel='Income2005'>
