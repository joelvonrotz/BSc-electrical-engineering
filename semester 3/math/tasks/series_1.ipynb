# %% [markdown]
# # Serie 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Aufgabe 1.1

# %%
# a)
x = pd.Series([4,2,1,3,3,5,7])
print("a)\n",x)

# b)
print("b) x[2] =", x[2])

# c)
print("c) x[0] =", x[0])
print("   x[3] =", x[3])

# d)
print("d) len(x) =", len(x))

# e) - Addiert jedem Element der Liste 2 hinzu
print("e)",x+2)

# f) - Addiert alle Elemente zusammen
print("f)",np.sum(x+2))

# g) - Gibt eine Bool-Liste zurück für jedes Element!
print("g)", x <= 3)

# h) - Gibt nur Elemente zurück, welche kleiner gleich 3 sind.
print("h) x[x <= 3]\n", x[x <= 3])

# i) - Sortiert die Elemente nach Wert
print("i) np.sort(x)\n", np.sort(x))

# j) - Gibt die Index an, welche 
print(f"j) np.argsort(x)\n{np.argsort(x)}\n{np.argsort(x)+1}")

# k)
print(f"k) {x[3]} -> x[3] = 8 -> ",end="")
x[3] = 8
print(x[3])
# Out:
# a)
#  0    4
# 1    2
# 2    1
# 3    3
# 4    3
# 5    5
# 6    7
# dtype: int64
# b) x[2] = 1
# c) x[0] = 4
#    x[3] = 3
# d) len(x) = 7
# e) 0    6
# 1    4
# 2    3
# 3    5
# 4    5
# 5    7
# 6    9
# dtype: int64
# f) 39
# g) 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# dtype: bool
# h) x[x <= 3]
#  1    2
# 2    1
# 3    3
# 4    3
# dtype: int64
# i) np.sort(x)
#  [1 2 3 3 4 5 7]
# j) np.argsort(x)
# 0    2
# 1    1
# 2    3
# 3    4
# 4    0
# 5    5
# 6    6
# dtype: int64
# 0    3
# 1    2
# 2    4
# 3    5
# 4    1
# 5    6
# 6    7
# dtype: int64
# k) 3 -> x[3] = 8 -> 8

# %% [markdown]
# ## Aufgabe 1.2

# %%
weight = pd.Series([60, 72, 57, 90, 95, 72])  # kg
height = pd.Series([1.75, 1.80, 1.65, 1.90, 1.74, 1.91])  # m

BMI = weight / (height**2)

print(BMI)
# Out:
# 0    19.591837
# 1    22.222222
# 2    20.936639
# 3    24.930748
# 4    31.377989
# 5    19.736301
# dtype: float64

# %% [markdown]
# ## Aufgabe 1.3

# %%
fahrenheit = pd.Series([51.9, 51.8, 51.9, 53])

celsius = 5/9 * (fahrenheit - 32)
print(f"{fahrenheit=}\n\n{celsius=}")

diff = fahrenheit - pd.Series([48, 48.2, 48, 48.7])
print(f"{diff=}")
# Out:
# fahrenheit=0    51.9
# 1    51.8
# 2    51.9
# 3    53.0
# dtype: float64
#
# celsius=0    11.055556
# 1    11.000000
# 2    11.055556
# 3    11.666667
# dtype: float64
# diff=0    3.9
# 1    3.6
# 2    3.9
# 3    4.3
# dtype: float64

# %% [markdown]
# ## Aufgabe 1.4

# %%
winner = pd.Series([182,191, 185, 185, 182, 182, 188, 188, 188, 185, 185, 177, 182, 182, 193, 183, 179, 179, 175])
opponent = pd.Series([191,165, 187, 175, 193, 185, 187, 188, 173, 180, 177, 183, 185, 180, 180, 182, 178, 178, 173])

print(f"a) \n{len(winner)=}\n{len(opponent)=}\n{(len(winner)==len(opponent))=}")
print(f"b) \n{winner[5:10]=}\n")
print(f"c) \n",winner[[2,4,9,10,11]])

winner[[6,7]] = 189
print(f"d)\n",winner[6:8])
print(f"e)\n{winner.mean()=:,.2f} [vs.] {opponent.mean()=:,.2f}")

print(f"f)\nDifferenz: {winner.mean() - opponent.mean():,.2f} cm")
print(f"g) {winner.var()=:,.2f}, {winner.std()=:,.2f}")

sum = 0
for value in winner:
  sum += (value - winner.mean())**2

variance = sum/(len(winner)-1)
standard_deviation = np.sqrt(variance)

print(f"h) {variance=:,.2f}, {standard_deviation=:,.2f}")
# Out:
# a)
# len(winner)=19
# len(opponent)=19
# (len(winner)==len(opponent))=True
# b)
# winner[5:10]=5    182
# 6    188
# 7    188
# 8    188
# 9    185
# dtype: int64
#
# c)
#  2     185
# 4     182
# 9     185
# 10    185
# 11    177
# dtype: int64
# d)
#  6    189
# 7    189
# dtype: int64
# e)
# winner.mean()=183.84 [vs.] opponent.mean()=181.05
# f)
# Differenz: 2.79 cm
# g) winner.var()=22.25, winner.std()=4.72
# h) variance=22.25, standard_deviation=4.72

# %% [markdown]
# ## Aufgabe 1.5

# %%
# a) load data and start at column 0 (first column)
data = pd.read_csv("./child.csv", sep=",", index_col=0)
data
# Out:
#                  Average.disposable.income  Children.in.poor.homes  \
# Australia                        20.813221               11.791352
# Austria                          22.162446                6.166094
# Belgium                          21.401153                9.974720
# Canada                           25.606245               15.057585
# Czech Republic                   10.849270               10.270000
# Denmark                          23.175894                2.740000
# Finland                          22.027651                4.170000
# France                           18.960382                7.640000
# Germany                          19.894067               16.289270
# Greece                           17.183647               13.230296
# Hungary                           9.463130                8.724203
# Iceland                          22.286852                8.250000
# Ireland                          22.364689               16.299416
# ...

# %%
# b) 
print(f"{data.shape=}")

# c) describe data
data_described = data.describe()
print(f"Mittelwert -------------------------------- \n{data_described.mean()}\n\n")
print(f"Median ------------------------------------ \n{data_described.median()}\n\n")

# d) Check for Netherlands
print(f"d) {data.index}")
print(f"   Netherlands {'Netherlands' in data.index}")
print(f"   China {'China' in data.index}")
# Out:
# data.shape=(30, 21)
# Mittelwert --------------------------------
# Average.disposable.income         19.361750
# Children.in.poor.homes            13.993421
# Educational.Deprivation            6.848588
# Overcrowding                      30.799019
# Poor.environmental.conditions     22.723853
# Average.mean.literacy.score      376.744830
# Literacy.inequality                4.998563
# Youth.NEET.rate                   12.427179
# Low.birth.weight                   9.121417
# Infant.mortality                   9.853553
# Breastfeeding.rates               66.757361
# Vaccination.rates..pertussis.     73.811649
# Vaccination.rates.measles.        72.315797
# Physical.activity                 20.549075
# Mortality.rates                   24.435598
# Suicide.rates                      9.619802
# Smoking                           16.400544
# Drunkenness                       15.268974
# Teenage.births                    20.552166
# Bullying                          12.634454
# ...

# %%
# e) 
# first show all column names
data.columns
# Out:
# Index(['Average.disposable.income', 'Children.in.poor.homes',
#        'Educational.Deprivation', 'Overcrowding',
#        'Poor.environmental.conditions', 'Average.mean.literacy.score',
#        'Literacy.inequality', 'Youth.NEET.rate', 'Low.birth.weight',
#        'Infant.mortality', 'Breastfeeding.rates',
#        'Vaccination.rates..pertussis.', 'Vaccination.rates.measles.',
#        'Physical.activity', 'Mortality.rates', 'Suicide.rates', 'Smoking',
#        'Drunkenness', 'Teenage.births', 'Bullying', 'Liking.school'],
#       dtype='object')

# %%
# grab the drunkenness column, sort it descending...
drunk = data.sort_values(by='Drunkenness', ascending=False)

# ...and select the top 5
drunk['Drunkenness'].head(5)
# Out:
# Denmark           24.8
# Finland           22.4
# United Kingdom    22.1
# Poland            19.9
# Canada            18.8
# Name: Drunkenness, dtype: float64

# %%
# f) Infant Mortality
data.nsmallest(columns='Infant.mortality',n=1)
# Out:
#          Average.disposable.income  Children.in.poor.homes  \
# Iceland                  22.286852                    8.25
#
#          Educational.Deprivation  Overcrowding  Poor.environmental.conditions  \
# Iceland                      0.4     21.652526                      15.534688
#
#          Average.mean.literacy.score  Literacy.inequality  Youth.NEET.rate  \
# Iceland                       493.67             1.654064              NaN
#
#          Low.birth.weight  Infant.mortality  ...  \
# Iceland               3.9               2.3  ...
#
#          Vaccination.rates..pertussis.  Vaccination.rates.measles.  \
# Iceland                           97.0                        94.0
#
#          Physical.activity  Mortality.rates  Suicide.rates  Smoking  \
# Iceland               20.6            16.95       7.841312     13.5
#
#          Drunkenness  Teenage.births  Bullying  Liking.school
# Iceland         10.5            16.9       5.4           36.6
#
# [1 rows x 21 columns]

# %%
# g) 
physical_mean = data['Physical.activity'].mean()
print(f"mean = {physical_mean}")
data.sort_values(by='Physical.activity',ascending=False).loc[data['Physical.activity'] < physical_mean]['Physical.activity']
# Out:
# mean = 20.134615384615383
# Turkey            20.0
# Austria           19.6
# Hungary           19.5
# Belgium           19.1
# United Kingdom    18.7
# Mexico            18.1
# Poland            17.3
# Germany           17.0
# Sweden            16.4
# Norway            15.6
# Greece            15.5
# Luxembourg        15.2
# Italy             15.1
# Portugal          14.6
# France            13.5
# Switzerland       13.1
# Name: Physical.activity, dtype: float64

# %% [markdown]
# ## Aufgabe 1.6

# %%
# a)
fuel = pd.read_csv('./d.fuel.dat', sep=',', index_col=0)
fuel
# Out:
#     weight  mpg     type
# X
# 1     2560   33    Small
# 2     2345   33    Small
# 3     1845   37    Small
# 4     2260   32    Small
# 5     2440   32    Small
# 6     2285   26    Small
# 7     2275   33    Small
# 8     2350   28    Small
# 9     2295   25    Small
# 10    1900   34    Small
# 11    2390   29    Small
# 12    2075   35    Small
# 13    2330   26    Small
# 14    3320   20   Sporty
# 15    2885   27   Sporty
# 16    3310   19   Sporty
# 17    2695   30   Sporty
# 18    2170   33   Sporty
# 19    2710   27   Sporty
# 20    2775   24   Sporty
# 21    2840   26   Sporty
# 22    2485   28   Sporty
# 23    2670   27  Compact
# 24    2640   23  Compact
# 25    2655   26  Compact
# 26    3065   25  Compact
# 27    2750   24  Compact
# 28    2920   26  Compact
# 29    2780   24  Compact
# 30    2745   25  Compact
# 31    3110   21  Compact
# 32    2920   21  Compact
# 33    2645   23  Compact
# 34    2575   24  Compact
# 35    2935   23  Compact
# ...

# %%
# b)

fuel.loc[5,:]
# Out:
# weight     2440
# mpg          32
# type      Small
# Name: 5, dtype: object

# %%
# c)
