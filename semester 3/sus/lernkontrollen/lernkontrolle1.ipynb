# %%
# import needed libraries for all plot and numbering stuff
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# [CONFIGS] --------------------------------------
mpl.rcParams['figure.dpi'] = 120

# %% [markdown]
# ![](../assets/thumbnail.jpg)
#
# # **Lernkontrolle 1**

# %% [markdown]
# ## Aufgabe 5
#
# Hier muss die Leistungsformel
#
# $$
# n = 2: \frac{3}{5}\quad
# n = 4: \frac{5}{9}\quad
# \cdots\quad
# n = 1000: \frac{1001}{2001}\quad
# n = 20000: \frac{20001}{40001}\quad
# n = \infty: \frac{1}{2}
# $$
#
# $$
# P_x = \lim_{n\rightarrow }
# $$

# %%
dt = 1
t = np.arange(-3,8,dt)
y = (t >= 0).astype(int)

plt.axvline(0,linewidth=1,c="black")
plt.axhline(0,linewidth=1,c="black")

plt.plot(t,y,'bs')
plt.xticks(t)
plt.yticks(np.arange(-1,5,1))
plt.grid(True)
plt.show()
