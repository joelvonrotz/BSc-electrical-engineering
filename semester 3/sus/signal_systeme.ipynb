# %%
# import needed libraries for all plot and numbering stuff
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# [CONFIGS] --------------------------------------
mpl.rcParams['figure.dpi'] = 120

# %% [markdown]
# ![](./assets/thumbnail.jpg)
#
# # **Signal & Systeme**

# %% [markdown]
# ## Funktion $si(t)$
#
# $$
# si(t) = \frac{sin(t)}{t}
# $$

# %%
# draw the si(t) function
dt = 0.01

t = np.arange(-50, 50, dt)

plt.plot(t, np.sin(t)/t, '-')
plt.grid(True)
plt.title("si(t)")
plt.show()

# %% [markdown]
# ## Dirac-Impuls
#
# $$
#
# $$

# %%
# draw the dirac impuls function
dt = 1
t = np.arange(-5,6,dt)
y = (t == 0).astype(int)

plt.axvline(0,linewidth=1,c="black")
plt.axhline(0,linewidth=1,c="black")
plt.plot(t,y,'bs')
plt.xticks(t)
plt.yticks(np.arange(-1,3,1))
plt.grid(True)
plt.show()

# %% [markdown]
# # Hasenzucht

# %%
a = 1/2*(1+np.sqrt(5))
b = 1/2*(1-np.sqrt(5))
A = 1/2*(1+1/np.sqrt(5))
B = 1/2*(1-1/np.sqrt(5))

k = np.arange(0,11,1)

plt.plot(k, A*a**k+B*b**k,'-o')
plt.grid(True)
plt.show()
